# %%
import requests
from kafka import KafkaProducer
import json
import time

# %%
bootstrap_servers = 'kafka:9092'
topic_name = 'nba-API-data-2'
producer = KafkaProducer(bootstrap_servers=bootstrap_servers, value_serializer=lambda x: json.dumps(x).encode('utf-8'))

# %%
base_url = 'https://www.balldontlie.io/api/v1'
seasons = ['1995','1996', '1997', '2005', '2006', '2007', '2011', '2012', '2013']

# %%
def get_players():
    for player_id in range(2500, 2851):
        for season in seasons:
            player_details = {
                'id': player_id,
                'first_name': None,  # Placeholder for first name
                'last_name': None  # Placeholder for last name
            }
            
            while True:
                player_url = f'{base_url}/players/{player_id}'
                response = requests.get(player_url)
                
                if response.status_code == 200:
                    player_data = response.json()
                    if 'first_name' in player_data:
                        player_details['first_name'] = player_data['first_name']
                    if 'last_name' in player_data:
                        player_details['last_name'] = player_data['last_name']
                    break  # Break the while loop if the response code is 200
                else:
                    print(f"Request for player {player_id} failed. Retrying...")
                    time.sleep(10)  # Wait for 10 second before retrying the request
            
            yield player_details, season
            
def get_season_stats(player_id, season):
    url = f'{base_url}/season_averages?season={season}&player_ids[]={player_id}'
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            season_stats = response.json()
            if 'data' in season_stats and season_stats['data']:
                return season_stats['data']
        except json.JSONDecodeError:
            pass
    
    return None

# %%
for player_details, season in get_players():
    player_id = player_details['id']
    player_season_stats = get_season_stats(player_id, season)

    if player_season_stats is not None:
        full_name = f"{player_details['first_name']} {player_details['last_name']}"

        player_data = {
            'id': player_id,
            'full_name': full_name,
            'season': season,
            'season_stats': player_season_stats
        }
        producer.send(topic_name, value=player_data)
        
        print(f"Sent: {player_id} - {season}")

print("Loop exited")
# Out:
# Request for player 2503 failed. Retrying...
# Request for player 2503 failed. Retrying...
# Request for player 2503 failed. Retrying...
# Request for player 2503 failed. Retrying...
# Request for player 2506 failed. Retrying...
# Request for player 2506 failed. Retrying...
# Request for player 2506 failed. Retrying...
# Request for player 2506 failed. Retrying...
# Request for player 2510 failed. Retrying...
# Request for player 2510 failed. Retrying...
# Request for player 2510 failed. Retrying...
# Request for player 2513 failed. Retrying...
# Request for player 2513 failed. Retrying...
# Request for player 2513 failed. Retrying...
# Request for player 2513 failed. Retrying...
# Request for player 2516 failed. Retrying...
# Request for player 2516 failed. Retrying...
# Request for player 2516 failed. Retrying...
# Request for player 2516 failed. Retrying...
# Request for player 2520 failed. Retrying...
# Request for player 2520 failed. Retrying...
# Request for player 2520 failed. Retrying...
# Request for player 2520 failed. Retrying...
# Request for player 2523 failed. Retrying...
# Request for player 2523 failed. Retrying...
# Request for player 2523 failed. Retrying...
# Request for player 2526 failed. Retrying...
# Request for player 2526 failed. Retrying...
# Request for player 2526 failed. Retrying...
# Request for player 2526 failed. Retrying...
# Request for player 2530 failed. Retrying...
# Request for player 2530 failed. Retrying...
# Request for player 2530 failed. Retrying...
# Request for player 2530 failed. Retrying...
# Request for player 2533 failed. Retrying...
# Request for player 2533 failed. Retrying...
# Request for player 2533 failed. Retrying...
# Request for player 2533 failed. Retrying...
# Request for player 2536 failed. Retrying...
# Request for player 2536 failed. Retrying...
# Request for player 2536 failed. Retrying...
# Request for player 2540 failed. Retrying...
# Request for player 2540 failed. Retrying...
# Request for player 2540 failed. Retrying...
# Request for player 2540 failed. Retrying...
# Request for player 2543 failed. Retrying...
# Request for player 2543 failed. Retrying...
# Request for player 2543 failed. Retrying...
# Request for player 2543 failed. Retrying...
# Request for player 2546 failed. Retrying...
# Request for player 2546 failed. Retrying...
# Request for player 2546 failed. Retrying...
# Request for player 2546 failed. Retrying...
# Request for player 2550 failed. Retrying...
# Request for player 2550 failed. Retrying...
# Request for player 2550 failed. Retrying...
# Request for player 2553 failed. Retrying...
# Request for player 2553 failed. Retrying...
# Request for player 2553 failed. Retrying...
# Request for player 2553 failed. Retrying...
# Request for player 2556 failed. Retrying...
# Request for player 2556 failed. Retrying...
# Request for player 2556 failed. Retrying...
# Request for player 2556 failed. Retrying...
# Request for player 2560 failed. Retrying...
# Request for player 2560 failed. Retrying...
# Request for player 2560 failed. Retrying...
# Request for player 2560 failed. Retrying...
# Request for player 2563 failed. Retrying...
# Request for player 2563 failed. Retrying...
# Request for player 2563 failed. Retrying...
# Request for player 2566 failed. Retrying...
# Request for player 2566 failed. Retrying...
# Request for player 2566 failed. Retrying...
# Request for player 2566 failed. Retrying...
# Request for player 2570 failed. Retrying...
# Request for player 2570 failed. Retrying...
# Request for player 2570 failed. Retrying...
# Request for player 2570 failed. Retrying...
# Request for player 2573 failed. Retrying...
# Request for player 2573 failed. Retrying...
# Request for player 2573 failed. Retrying...
# Request for player 2573 failed. Retrying...
# Request for player 2576 failed. Retrying...
# Request for player 2576 failed. Retrying...
# Request for player 2576 failed. Retrying...
# Request for player 2580 failed. Retrying...
# Request for player 2580 failed. Retrying...
# Request for player 2580 failed. Retrying...
# Request for player 2580 failed. Retrying...
# Request for player 2583 failed. Retrying...
# Request for player 2583 failed. Retrying...
# Request for player 2583 failed. Retrying...
# Request for player 2583 failed. Retrying...
# Request for player 2586 failed. Retrying...
# Request for player 2586 failed. Retrying...
# Request for player 2586 failed. Retrying...
# Request for player 2586 failed. Retrying...
# Request for player 2590 failed. Retrying...
# Request for player 2590 failed. Retrying...
# Request for player 2590 failed. Retrying...
# Request for player 2593 failed. Retrying...
# Request for player 2593 failed. Retrying...
# Request for player 2593 failed. Retrying...
# Request for player 2593 failed. Retrying...
# Request for player 2596 failed. Retrying...
# Request for player 2596 failed. Retrying...
# Request for player 2596 failed. Retrying...
# Request for player 2596 failed. Retrying...
# Request for player 2600 failed. Retrying...
# Request for player 2600 failed. Retrying...
# Request for player 2600 failed. Retrying...
# Request for player 2600 failed. Retrying...
# Request for player 2603 failed. Retrying...
# Request for player 2603 failed. Retrying...
# Request for player 2603 failed. Retrying...
# Request for player 2603 failed. Retrying...
# Request for player 2606 failed. Retrying...
# Request for player 2606 failed. Retrying...
# Request for player 2606 failed. Retrying...
# Request for player 2610 failed. Retrying...
# Request for player 2610 failed. Retrying...
# Request for player 2610 failed. Retrying...
# Request for player 2610 failed. Retrying...
# Request for player 2613 failed. Retrying...
# Request for player 2613 failed. Retrying...
# Request for player 2613 failed. Retrying...
# Request for player 2613 failed. Retrying...
# Request for player 2616 failed. Retrying...
# Request for player 2616 failed. Retrying...
# Request for player 2616 failed. Retrying...
# Request for player 2616 failed. Retrying...
# Request for player 2620 failed. Retrying...
# Request for player 2620 failed. Retrying...
# Request for player 2620 failed. Retrying...
# Request for player 2623 failed. Retrying...
# Request for player 2623 failed. Retrying...
# Request for player 2623 failed. Retrying...
# Request for player 2623 failed. Retrying...
# Request for player 2626 failed. Retrying...
# Request for player 2626 failed. Retrying...
# Request for player 2626 failed. Retrying...
# Request for player 2626 failed. Retrying...
# Request for player 2630 failed. Retrying...
# Request for player 2630 failed. Retrying...
# Request for player 2630 failed. Retrying...
# Request for player 2630 failed. Retrying...
# Request for player 2633 failed. Retrying...
# Request for player 2633 failed. Retrying...
# Request for player 2633 failed. Retrying...
# Request for player 2633 failed. Retrying...
# Request for player 2636 failed. Retrying...
# Request for player 2636 failed. Retrying...
# Request for player 2636 failed. Retrying...
# Request for player 2640 failed. Retrying...
# Request for player 2640 failed. Retrying...
# Request for player 2640 failed. Retrying...
# Request for player 2640 failed. Retrying...
# Request for player 2643 failed. Retrying...
# Request for player 2643 failed. Retrying...
# Request for player 2643 failed. Retrying...
# Request for player 2643 failed. Retrying...
# Request for player 2646 failed. Retrying...
# Request for player 2646 failed. Retrying...
# Request for player 2646 failed. Retrying...
# Request for player 2646 failed. Retrying...
# Request for player 2650 failed. Retrying...
# Request for player 2650 failed. Retrying...
# Request for player 2650 failed. Retrying...
# Request for player 2653 failed. Retrying...
# Request for player 2653 failed. Retrying...
# Request for player 2653 failed. Retrying...
# Request for player 2653 failed. Retrying...
# Request for player 2656 failed. Retrying...
# Request for player 2656 failed. Retrying...
# Request for player 2656 failed. Retrying...
# Request for player 2656 failed. Retrying...
# Request for player 2660 failed. Retrying...
# Request for player 2660 failed. Retrying...
# Request for player 2660 failed. Retrying...
# Request for player 2660 failed. Retrying...
# Request for player 2663 failed. Retrying...
# Request for player 2663 failed. Retrying...
# Request for player 2663 failed. Retrying...
# Request for player 2666 failed. Retrying...
# Request for player 2666 failed. Retrying...
# Request for player 2666 failed. Retrying...
# Request for player 2666 failed. Retrying...
# Request for player 2670 failed. Retrying...
# Request for player 2670 failed. Retrying...
# Request for player 2670 failed. Retrying...
# Request for player 2670 failed. Retrying...
# Request for player 2673 failed. Retrying...
# Request for player 2673 failed. Retrying...
# Request for player 2673 failed. Retrying...
# Request for player 2673 failed. Retrying...
# Request for player 2676 failed. Retrying...
# Request for player 2676 failed. Retrying...
# Request for player 2676 failed. Retrying...
# Request for player 2680 failed. Retrying...
# Request for player 2680 failed. Retrying...
# Request for player 2680 failed. Retrying...
# Request for player 2680 failed. Retrying...
# Request for player 2683 failed. Retrying...
# Request for player 2683 failed. Retrying...
# Request for player 2683 failed. Retrying...
# Request for player 2683 failed. Retrying...
# Request for player 2686 failed. Retrying...
# Request for player 2686 failed. Retrying...
# Request for player 2686 failed. Retrying...
# Request for player 2686 failed. Retrying...
# Request for player 2690 failed. Retrying...
# Request for player 2690 failed. Retrying...
# Request for player 2690 failed. Retrying...
# Request for player 2693 failed. Retrying...
# Request for player 2693 failed. Retrying...
# Request for player 2693 failed. Retrying...
# Request for player 2693 failed. Retrying...
# Request for player 2696 failed. Retrying...
# Request for player 2696 failed. Retrying...
# Request for player 2696 failed. Retrying...
# Request for player 2696 failed. Retrying...
# Request for player 2700 failed. Retrying...
# Request for player 2700 failed. Retrying...
# Request for player 2700 failed. Retrying...
# Request for player 2700 failed. Retrying...
# Request for player 2703 failed. Retrying...
# Request for player 2703 failed. Retrying...
# Request for player 2703 failed. Retrying...

# %%
producer.flush()
producer.close()
