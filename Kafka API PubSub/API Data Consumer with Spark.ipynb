# %% [markdown]
# # Consume API Data from Kafka with Spark

# %% [markdown]
# For consuming the API data we use Spark to directly read the data from Kafka and we subscribe to the corresponding topic. We made use of the Spark Kafka Package, consumed the data, cleaned it and uploaded it to our MongoDB Collection for the API data.

# %% [markdown]
# ## Import Packages

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, IntegerType
from pyspark.sql.functions import from_json, col
from pyspark.sql.functions import udf, round
from pyspark.sql.types import DoubleType
from pyspark.sql.functions import split
import pymongo as mdb

# %% [markdown]
# ## Create Spark Session

# %%
spark = (SparkSession
         .builder
         .appName('nbaConsumer')
         .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0")
         .getOrCreate())
sc = spark.sparkContext

# %% [markdown]
# ## Create Schema for Spark Dataframe

# %%
schema_player_stats = StructType([
    StructField("player_id", IntegerType(), True),
    StructField("full_name", StringType(), True),
    StructField("season", IntegerType(), True),
    StructField("ast", DoubleType(), True),
    StructField("blk", DoubleType(), True),
    StructField("dreb", DoubleType(), True),
    StructField("fg3_pct", DoubleType(), True),
    StructField("fg3a", DoubleType(), True),
    StructField("fg3m", DoubleType(), True),
    StructField("fg_pct", DoubleType(), True),
    StructField("fga", DoubleType(), True),
    StructField("fgm", DoubleType(), True),
    StructField("ft_pct", DoubleType(), True),
    StructField("fta", DoubleType(), True),
    StructField("ftm", DoubleType(), True),
    StructField("games_played", IntegerType(), True),
    StructField("min", StringType(), True),
    StructField("oreb", DoubleType(), True),
    StructField("pf", DoubleType(), True),
    StructField("pts", DoubleType(), True),
    StructField("reb", DoubleType(), True),
    StructField("stl", DoubleType(), True),
    StructField("turnover", DoubleType(), True)
])

# %% [markdown]
# ## Read Messages into Spark Dataframe

# %%
df = spark.read \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "kafka:9092") \
    .option("subscribe", "NBA-API-TOPIC") \
    .option("startingOffsets", "earliest") \
    .option("endingOffsets", "latest") \
    .load()

df = df.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

parsed_df = df.withColumn("parsed_value", from_json(col("value"), schema_player_stats))

final_df = parsed_df.select("key", "parsed_value.*")

final_df.show()
# Out:
# +----+---------+--------------+------+----+----+----+-------+----+----+------+-----+----+------+----+----+------------+-----+----+----+-----+-----+----+--------+
# | key|player_id|     full_name|season| ast| blk|dreb|fg3_pct|fg3a|fg3m|fg_pct|  fga| fgm|ft_pct| fta| ftm|games_played|  min|oreb|  pf|  pts|  reb| stl|turnover|
# +----+---------+--------------+------+----+----+----+-------+----+----+------+-----+----+------+----+----+------------+-----+----+----+-----+-----+----+--------+
# |null|       67|MarShon Brooks|  2011|2.34|0.27|2.32|  0.313|2.68|0.84| 0.428|11.43|4.89| 0.764|2.64|2.02|          56|29:26|1.25|2.07|12.64| 3.57|0.93|    2.11|
# |null|       67|MarShon Brooks|  2012|1.04|0.22|0.99|  0.273|0.75|0.21| 0.463| 4.59|2.12| 0.734|1.29|0.95|          73|12:31|0.44|1.27|  5.4| 1.42|0.47|    0.95|
# |null|       67|MarShon Brooks|  2013|0.76|0.12|1.33|   0.52|0.76|0.39| 0.456| 3.79|1.73| 0.727|1.33|0.97|          33| 9:37| 0.3|0.64| 4.82| 1.64|0.42|    0.73|
# |null|       71| Lorenzo Brown|  2013|1.71|0.13|0.83|    0.1|1.25|0.13| 0.302| 3.58|1.08| 0.692|0.54|0.38|          24| 9:17|0.33|0.79| 2.67| 1.17|0.54|    0.67|
# |null|       90|   Omri Casspi|  2011|1.02|0.32|2.54|  0.315|2.58|0.82| 0.403| 6.34|2.55| 0.685|1.66|1.14|          65|20:39|0.97|1.77| 7.06| 3.51|0.57|    0.98|
------------+------+----+----+----+-------+----+----+------+-----+----+------+----+----+------------+-----+----+----+-----+-----+----+--------+
# only showing top 20 rows

# %% [markdown]
# ## View Schema of Dataframe

# %%
final_df.printSchema()
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- player_id: integer (nullable = true)
#  |-- full_name: string (nullable = true)
#  |-- season: integer (nullable = true)
#  |-- ast: double (nullable = true)
#  |-- blk: double (nullable = true)
#  |-- dreb: double (nullable = true)
#  |-- fg3_pct: double (nullable = true)
#  |-- fg3a: double (nullable = true)
#  |-- fg3m: double (nullable = true)
#  |-- fg_pct: double (nullable = true)
#  |-- fga: double (nullable = true)
#  |-- fgm: double (nullable = true)
#  |-- ft_pct: double (nullable = true)
#  |-- fta: double (nullable = true)
#  |-- ftm: double (nullable = true)
#  |-- games_played: integer (nullable = true)
#  |-- min: string (nullable = true)
#  |-- oreb: double (nullable = true)
#  |-- pf: double (nullable = true)
#  |-- pts: double (nullable = true)
#  |-- reb: double (nullable = true)
#  |-- stl: double (nullable = true)
#  |-- turnover: double (nullable = true)

# %% [markdown]
# ## Clean Data

# %% [markdown]
# ### Drop Columns

# %%
final_df = final_df.drop("key")

# %%
final_df = final_df.drop("player_id")

# %%
final_df.printSchema()
# Out:
# root
#  |-- full_name: string (nullable = true)
#  |-- season: integer (nullable = true)
#  |-- ast: double (nullable = true)
#  |-- blk: double (nullable = true)
#  |-- dreb: double (nullable = true)
#  |-- fg3_pct: double (nullable = true)
#  |-- fg3a: double (nullable = true)
#  |-- fg3m: double (nullable = true)
#  |-- fg_pct: double (nullable = true)
#  |-- fga: double (nullable = true)
#  |-- fgm: double (nullable = true)
#  |-- ft_pct: double (nullable = true)
#  |-- fta: double (nullable = true)
#  |-- ftm: double (nullable = true)
#  |-- games_played: integer (nullable = true)
#  |-- min: string (nullable = true)
#  |-- oreb: double (nullable = true)
#  |-- pf: double (nullable = true)
#  |-- pts: double (nullable = true)
#  |-- reb: double (nullable = true)
#  |-- stl: double (nullable = true)
#  |-- turnover: double (nullable = true)

# %% [markdown]
# ### Convert Minute String into Numeric Values

# %%
final_df.show(5)
# Out:
# +--------------+------+----+----+----+-------+----+----+------+-----+----+------+----+----+------------+-----+----+----+-----+----+----+--------+
# |     full_name|season| ast| blk|dreb|fg3_pct|fg3a|fg3m|fg_pct|  fga| fgm|ft_pct| fta| ftm|games_played|  min|oreb|  pf|  pts| reb| stl|turnover|
# +--------------+------+----+----+----+-------+----+----+------+-----+----+------+----+----+------------+-----+----+----+-----+----+----+--------+
# |MarShon Brooks|  2011|2.34|0.27|2.32|  0.313|2.68|0.84| 0.428|11.43|4.89| 0.764|2.64|2.02|          56|29:26|1.25|2.07|12.64|3.57|0.93|    2.11|
# |MarShon Brooks|  2012|1.04|0.22|0.99|  0.273|0.75|0.21| 0.463| 4.59|2.12| 0.734|1.29|0.95|          73|12:31|0.44|1.27|  5.4|1.42|0.47|    0.95|
# |MarShon Brooks|  2013|0.76|0.12|1.33|   0.52|0.76|0.39| 0.456| 3.79|1.73| 0.727|1.33|0.97|          33| 9:37| 0.3|0.64| 4.82|1.64|0.42|    0.73|
# | Lorenzo Brown|  2013|1.71|0.13|0.83|    0.1|1.25|0.13| 0.302| 3.58|1.08| 0.692|0.54|0.38|          24| 9:17|0.33|0.79| 2.67|1.17|0.54|    0.67|
# |   Omri Casspi|  2011|1.02|0.32|2.54|  0.315|2.58|0.82| 0.403| 6.34|2.55| 0.685|1.66|1.14|          65|20:39|0.97|1.77| 7.06|3.51|0.57|    0.98|
# +--------------+------+----+----+----+-------+----+----+------+-----+----+------+----+----+------------+-----+----+----+-----+----+----+--------+
# only showing top 5 rows

# %%
def convert_min_to_decimal(time_str):
    minutes, seconds = time_str.split(':')
    minutes = int(minutes)
    seconds = int(seconds)
    return minutes + seconds / 60

convert_to_decimal_udf = udf(convert_min_to_decimal, DoubleType())

final_df = final_df.withColumn('min', convert_to_decimal_udf(final_df['min']))

final_df = final_df.withColumn('min', round(final_df['min'], 1))

# %%
final_df.show()
# Out:
# +--------------+------+----+----+----+-------+----+----+------+-----+----+------+----+----+------------+----+----+----+-----+-----+----+--------+
# |     full_name|season| ast| blk|dreb|fg3_pct|fg3a|fg3m|fg_pct|  fga| fgm|ft_pct| fta| ftm|games_played| min|oreb|  pf|  pts|  reb| stl|turnover|
# +--------------+------+----+----+----+-------+----+----+------+-----+----+------+----+----+------------+----+----+----+-----+-----+----+--------+
# |MarShon Brooks|  2011|2.34|0.27|2.32|  0.313|2.68|0.84| 0.428|11.43|4.89| 0.764|2.64|2.02|          56|29.4|1.25|2.07|12.64| 3.57|0.93|    2.11|
# |MarShon Brooks|  2012|1.04|0.22|0.99|  0.273|0.75|0.21| 0.463| 4.59|2.12| 0.734|1.29|0.95|          73|12.5|0.44|1.27|  5.4| 1.42|0.47|    0.95|
# |MarShon Brooks|  2013|0.76|0.12|1.33|   0.52|0.76|0.39| 0.456| 3.79|1.73| 0.727|1.33|0.97|          33| 9.6| 0.3|0.64| 4.82| 1.64|0.42|    0.73|
# | Lorenzo Brown|  2013|1.71|0.13|0.83|    0.1|1.25|0.13| 0.302| 3.58|1.08| 0.692|0.54|0.38|          24| 9.3|0.33|0.79| 2.67| 1.17|0.54|    0.67|
# |   Omri Casspi|  2011|1.02|0.32|2.54|  0.315|2.58|0.82| 0.403| 6.34|2.55| 0.685|1.66|1.14|          65|20.7|0.97|1.77| 7.06| 3.51|0.57|    0.98|
# |   Omri Casspi|  2012|0.67|0.29|2.24|  0.329|1.81| 0.6| 0.394| 3.81| 1.5| 0.537|0.98|0.52|          42|12.0|0.48|1.07| 4.12| 2.71| 0.6|    0.52|
# |   Omri Casspi|  2013|1.24| 0.2|2.89|  0.347|2.48|0.86| 0.422| 5.77|2.44|  0.68|1.72|1.17|          71|18.1|0.77|1.41|  6.9| 3.66|0.62|    1.01|
# | Marcin Gortat|  2007|0.33|0.17|1.33|    0.0| 0.0| 0.0| 0.471| 2.83|1.33| 0.667| 0.5|0.33|           6| 6.7|1.33|0.67|  3.0| 2.67|0.17|    0.33|
# | Marcin Gortat|  2011|0.89| 1.5|7.18|    0.0|0.03| 0.0| 0.555|11.65|6.47| 0.649| 3.8|2.47|          66|32.0| 2.8|2.15|15.41| 9.98|0.73|    1.36|
# | Marcin Gortat|  2012|1.23|1.61|6.36|    0.0|0.05| 0.0| 0.521| 9.28|4.84| 0.652|2.26|1.48|          61|30.8| 2.1|2.08|11.15| 8.46|0.66|    1.62|
# | Marcin Gortat|  2013| 1.7|1.49|6.98|    1.0|0.01|0.01| 0.542|10.37|5.62| 0.686|2.83|1.94|          81|32.8|2.49|2.48|13.19| 9.47|0.51|    1.56|
# |  Andrew Bogut|  2005|2.34|0.83|4.68|    0.0|0.04| 0.0| 0.533| 7.39|3.94| 0.629|2.37|1.49|          82|28.6| 2.3|3.16| 9.37| 6.99| 0.6|    1.52|
# |  Andrew Bogut|  2006| 3.0|0.53| 6.3|    0.2|0.08|0.02| 0.553| 9.53|5.27| 0.577|2.94| 1.7|          66|34.0|2.55|3.27|12.26| 8.85|0.74|    2.27|
# |  Andrew Bogut|  2007|2.55|1.73|6.64|    0.0|0.09| 0.0| 0.511|11.67|5.96| 0.587|4.13|2.42|          78|34.9|3.14|3.26|14.35| 9.78|0.82|    2.21|
# |  Andrew Bogut|  2011|2.58| 2.0| 6.5|    0.0|0.08| 0.0| 0.449|11.33|5.08| 0.609|1.92|1.17|          12|30.4|1.83| 3.0|11.33| 8.33| 1.0|     2.0|
# |  Andrew Bogut|  2012|2.09|1.72|5.53|    1.0|0.03|0.03| 0.451| 5.75|2.59|   0.5|1.19|0.59|          32|24.5|2.13|2.66| 5.81| 7.66|0.63|    1.09|
# |  Andrew Bogut|  2013|1.67|1.81| 7.3|    0.0| 0.0| 0.0| 0.627|  5.6|3.51| 0.344|0.96|0.33|          67|26.4|2.72|3.13| 7.34|10.01| 0.7|    1.45|
# |  Amir Johnson|  2005| 1.0|0.67|0.33|  0.667| 1.0|0.67|   0.7| 3.33|2.33|   1.0|1.33|1.33|           3|12.8| 1.0|2.33| 6.67| 1.33| 0.0|    1.33|
# |  Amir Johnson|  2006|0.38|1.63|2.75|    0.0|0.38| 0.0| 0.545| 4.13|2.25| 0.786|1.75|1.38|           8|15.6|1.88|2.38| 5.88| 4.63|0.63|    1.13|
# |  Amir Johnson|  2007|0.47|1.32|2.39|    0.0| 0.0| 0.0| 0.558| 2.66|1.48| 0.673|0.89| 0.6|          62|12.4| 1.4|2.27| 3.56| 3.79|0.39|    0.63|
# +--------------+------+----+----+----+-------+----+----+------+-----+----+------+----+----+------------+----+----+----+-----+-----+----+--------+
# only showing top 20 rows

# %% [markdown]
# ### Drop Null/NA Values

# %%
number_of_rows = final_df.count()
print(f"The DataFrame has {number_of_rows} rows.")
# Out:
# The DataFrame has 3923 rows.

# %%
final_df = final_df.na.drop()

# %%
number_of_rows = final_df.count()
print(f"The DataFrame has {number_of_rows} rows.")
# Out:
# The DataFrame has 3922 rows.

# %% [markdown]
# ### Drop Duplicate Rows

# %%
number_of_rows = final_df.count()
print(f"The DataFrame has {number_of_rows} rows.")
# Out:
# The DataFrame has 3922 rows.

# %%
final_df = final_df.dropDuplicates()

# %%
number_of_rows = final_df.count()
print(f"The DataFrame has {number_of_rows} rows.")
# Out:
# The DataFrame has 3898 rows.

# %% [markdown]
# ## Upload Cleaned Data to MongoDB

# %% [markdown]
# ### Convert Spark Dataframe into Pandas Dataframe

# %%
mongo_upload_df = final_df.toPandas()

# %%
mongo_upload_df.head()
# Out:
#         full_name  season   ast   blk  dreb  fg3_pct  fg3a  fg3m  fg_pct  \
# 0      Malik Rose    2005  0.93  0.19  2.43    1.000  0.01  0.01   0.374
# 1     Paul Pierce    2013  2.37  0.41  4.29    0.373  4.00  1.49   0.451
# 2   Victor Claver    2013  0.57  0.14  1.43    0.167  0.86  0.14   0.405
# 3  Thaddeus Young    2013  2.30  0.46  3.92    0.308  3.70  1.14   0.454
# 4  Mitch Richmond    1996  4.17  0.30  3.21    0.428  5.89  2.52   0.454
#
#      fga  ...   fta   ftm  games_played   min  oreb    pf    pts   reb   stl  \
# 0   3.90  ...  1.90  1.49            72  15.5  1.17  2.01   4.42  3.60  0.60
# 1   9.49  ...  4.13  3.41            75  28.0  0.35  2.53  13.47  4.64  1.15
# 2   2.00  ...  0.52  0.48            21   8.7  0.43  0.76   2.24  1.86  0.14
# 3  16.24  ...  2.90  2.06            79  34.4  2.10  2.70  17.94  6.03  2.11
# 4  19.48  ...  6.56  5.64            81  37.8  0.73  2.60  25.86  3.94  1.46
#
#    turnover
# 0      1.11
# 1      2.04
# 2      0.52
# 3      2.09
# 4      2.93
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Create MongoDB Connection

# %%
client = mdb.MongoClient("mongodb://pt-n20.p4001.w3.cs.technikum-wien.at:4001")
db = client.nba_data
collection = db.season_stats_api

# %% [markdown]
# ### Convert Rows to Dictionaries for Key-Value-Form

# %%
records = mongo_upload_df.to_dict(orient='records')

# %% [markdown]
# ### Iterate over Dataframe and inset or update Collection

# %%
for record in records:
    # Use 'full_name' and 'season' as the unique identifiers
    unique_query = {'full_name': record['full_name'], 'season': record['season']}
    
    # Replace or insert the record
    result = collection.update_one(unique_query, {'$set': record}, upsert=True)

    # Check the result to see what operation was performed
    if result.matched_count > 0:
        if result.modified_count > 0:
            print(f"Updated document: {unique_query}")
        else:
            print(f"Document already exists and no update needed: {unique_query}")
    elif result.upserted_id is not None:
        print(f"Inserted new document: {unique_query}")
# Out:
# Document already exists and no update needed: {'full_name': 'Malik Rose', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Paul Pierce', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Victor Claver', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Thaddeus Young', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Mitch Richmond', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Zydrunas Ilgauskas', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Damon Jones', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Hedo Turkoglu', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Tayshaun Prince', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Flip Murray', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Keith Bogans', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Deron Williams', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Andrew Bynum', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Jack Haley', 'season': 1996}
# Updated document: {'full_name': 'Chris Johnson', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Rudy Gay', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Kawhi Leonard', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Donald Royal', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Alan Henderson', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Pooh Richardson', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Elliot Perry', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Terrell Brandon', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Bryant Stith', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Jerald Honeycutt', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Manu Ginobili', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Willie Green', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Udonis Haslem', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Keith Van Horn', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Matt Harpring', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Paul Pierce', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Vladimir Radmanovic', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Sebastian Telfair', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Dorell Wright', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Jarrett Jack', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Steve Scheffler', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'John Lucas III', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Dee Brown', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Kenneth Faried', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Anthony Tolliver', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Anthony Bowie', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Kurt Thomas', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Vitaly Potapenko', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Alonzo Mourning', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Malik Rose', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Al Harrington', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Eddie Gill', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'T.J. Ford', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'JJ Hickson', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Marco Belinelli', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Alec Burks', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Chandler Parsons', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Greg Anthony', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Aaron McKie', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Jason Terry', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'James Scott', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Etan Thomas', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Flip Murray', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Mo Williams', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Josh Childress', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Deron Williams', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Nate Robinson', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Charles Oakley', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Courtney Sims', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'C.J. Watson', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Ricky Ledo', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Terry Davis', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Scott Burrell', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Kevin Garnett', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Antoine Wright', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Anthony Roberson', 'season': 2006}
# Document already exists and no update needed: {'full_name': '
', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Keith Bogans', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Allan Ray', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Kyle Singler', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Eric Piatkowski', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Gary Trent', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Reggie Slater', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Shandon Anderson', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Keith McLeod', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Johan Petro', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Daniel Gibson', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Darius Miller', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Ben Wallace', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Eduardo Najera', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Gerald Wallace', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Matt Barnes', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Jan Vesely', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Pablo Prigioni', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Patrick Beverley', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Kentavious Caldwell-Pope', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Jodie Meeks', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Antonio Davis', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Ashraf Amaya', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Grant Long', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Clifford Rozier', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Ike Diogu', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Kendall Marshall', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Carmelo Anthony', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Jeff Grayer', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Eric Snow', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Ray Allen', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Mikki Moore', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Jackson Vroman', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Alan Anderson', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Oleksiy Pecherov', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Darryl Watkins', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Jerry Reynolds', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Greivis Vasquez', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Cory Higgins', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Phil Pressey', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Ray Owes', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Jimmy Oliver', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Daequan Cook', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Mike Harris', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Devin Ebanks', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Raymond Felton', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Ersan Ilyasova', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Jamal Crawford', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Anfernee Hardaway', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Andris Biedrins', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'David Wingate', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Nate McMillan', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Shavlik Randolph', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Gary Payton', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'B.J. Armstrong', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Hollis Thompson', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'David Benoit', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Jaren Jackson', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Corliss Williamson', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Steve Blake', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Josh Powell', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Jorge Garbajosa', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Andrea Bargnani', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Taj Gibson', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'James Harden', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'DeAndre Jordan', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Lance Thomas', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Aaron Williams', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Rick Brunson', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Earl Boykins', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Antawn Jamison', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Jason Maxiell', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Cartier Martin', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Daniel Orton', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Buck Williams', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Chris Webber', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Eddie House', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Ed Davis', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Jeremy Lin', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Joel Przybilla', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Slava Medvedenko', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Travis Diener', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Tony Smith', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Sharrod Ford', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Mickael Gelabale', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Mike Conley', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Walter McCarty', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Andy Toolson', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Geert Hammink', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Chauncey Billups', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Lavoy Allen', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Dirk Nowitzki', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Donald Hodge', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Harold Miner', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Derek Anderson', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Mo Williams', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Matt Bonner', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Andres Nocioni', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Chris Duhon', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Vincent Askew', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Francisco Garcia', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Deron Williams', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Matt Walsh', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Stephen Graham', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Craig Ehlo', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Donald Royal', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Andrew DeClercq', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Donyell Marshall', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Derrick Alston', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Eldridge Recasner', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Erick Dampier', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Troy Hudson', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Marcus Fizer', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Chris Andersen', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Jannero Pargo', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Al Jefferson', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Tyler Honeycutt', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Courtney Fortson', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Ryan Anderson', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Keith Tower', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Tracy McGrady', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Scot Pollard', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Damon Jones', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Kenny Thomas', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Adonal Foyle', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Eduardo Najera', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Raja Bell', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Mehmet Okur', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Tim Legler', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'James Lang', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Hilton Armstrong', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Johnny Newman', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Charles Jones', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Loy Vaught', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Etdrick Bohannon', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Jacque Vaughn', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Shawn Marion', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Steven Hunter', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Mike Dunleavy', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Nick Collison', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Jordan Farmar', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Quincy Douby', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Joel Anthony', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Quincy Acy', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Ian Clark', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Austin Rivers', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Derek Fisher', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Mehmet Okur', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Mickael Pietrus', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Josh Childress', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Francisco Garcia', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Bobby Jones', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'B.J. Armstrong', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Jamario Moon', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'John Stockton', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Byron Mullens', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Tracy Moore', 'season': 1995}
# Document already exists and no update needed: {'full_name': "Shaquille O'Neal", 'season': 1996}
# Document already exists and no update needed: {'full_name': 'DerMarr Johnson', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Mark Blount', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Jake Voskuhl', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Jarvis Hayes', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Travis Outlaw', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Sean Rooks', 'season': 1997}
# Document already exists and no update needed: {'full_name': "Jermaine O'Neal", 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Kevin Salvadori', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Jason Hart', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Gerald Wallace', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Gerald Wallace', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Mike Wilks', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Royal Ivey', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Pape Sow', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Andray Blatche', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Sean Elliott', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Terrel Harris', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Eric Gordon', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Arvydas Sabonis', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Hakeem Olajuwon', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Tom Gugliotta', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Bo Outlaw', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Jannero Pargo', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Andrea Bargnani', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Joel Anthony', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Othyus Jeffers', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Gerald Green', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Ruben Patterson', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Stephen Jackson', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Terry Mills', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Sean Elliott', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Derek Strong', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'David Vaughn', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Malcolm Thomas', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Devin Harris', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Channing Frye', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Marc Jackson', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Jamaal Tinsley', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Qyntel Woods', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Jason Kapono', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Willie Anderson', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Chuck Hayes', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Gary Payton', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Gerald Wilkins', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Morris Almond', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Kevin Durant', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Zaza Pachulia', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Robert Werdann', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Brian Grant', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Eric Williams', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Junior Burrough', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Marcus Banks', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Tyrus Thomas', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Vince Carter', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Lou Williams', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Isaiah Rider', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Hedo Turkoglu', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Shareef Abdur-Rahim', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'James Collins', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Richard Jefferson', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Jason Collins', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Kwame Brown', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Sasha Vujacic', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Martell Webster', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Dwayne Schintzius', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'John Lucas III', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Mark Bryant', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Ryan Hollins', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Dominic McGuire', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Marcus Thornton', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Jimmer Fredette', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Adonis Thomas', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Al-Farouq Aminu', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Juwan Howard', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Marcin Gortat', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Chris Mills', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Jamal Mashburn', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Anthony Goldwire', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Shandon Anderson', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Michael Bradley', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Francisco Elson', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Tony Allen', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Arron Afflalo', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Alec Burks', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'JaVale McGee', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Jeff Grayer', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Jason Hart', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Earl Watson', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Caron Butler', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Drew Gooden', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Mike Wilks', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Charles Oakley', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Wayman Tisdale', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Eric Leckner', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Brandan Wright', 'season': 2007}
# Updated document: {'full_name': 'Marcus Williams', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Elliot Williams', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Jeffery Taylor', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Chris Babb', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Kyle Korver', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Frank Brickowski', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Robert Pack', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Nazr Mohammed', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Roger Mason Jr.', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Dwyane Wade', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Kevin Willis', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Aaron Williams', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Howard Nathan', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Shea Seals', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Hedo Turkoglu', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Kevin Salvadori', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Slava Medvedenko', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Benoit Benjamin', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'David Lee', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Mile Ilic', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Dell Curry', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Danny Ferry', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Darrell Arthur', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'DeMarre Carroll', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Kevin Love', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Derrick Rose', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Robert Horry', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Kenny Smith', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Darrell Armstrong', 'season': 1995}
# ...
# Document already exists and no update needed: {'full_name': 'JJ Hickson', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Maalik Wayns', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Avery Bradley', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Danilo Gallinari', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Chris Bosh', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Kirk Hinrich', 'season': 2012}
# Updated document: {'full_name': 'Charles Smith', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Deron Williams', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Kendall Gill', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Taurean Green', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Mookie Blaylock', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Rodney Stuckey', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Jeremy Tyler', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'J.J. Barea', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Robin Lopez', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Tracy Murray', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'John Wallace', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Andrew Bogut', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Kosta Koufos', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Stacey Augmon', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Trevor Ruffin', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Greg Minor', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Cherokee Parks', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Andrei Kirilenko', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Mike James', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Marquis Daniels', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Andre Barrett', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Jared Sullinger', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Paul Millsap', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Marvin Williams', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Steve Nash', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Steve Francis', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Juan Dixon', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Brandon Bass', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Nate Robinson', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'David Robinson', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Patrick Ewing', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Muggsy Bogues', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Nick Young', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Glen Davis', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Micheal Williams', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Josh Selby', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Eric Piatkowski', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Troy Murphy', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Junior Harrington', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Sean May', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Samardo Samuels', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Dexter Pittman', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'JR Smith', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Lou Williams', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Kenyon Martin', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Corey Maggette', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Shane Battier', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Carlos Delfino', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Carlos Delfino', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Terry Mills', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Donell Taylor', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Nate McMillan', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Dell Curry', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Hot Rod,Williams', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Chris Wright', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Jared Cunningham', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'John Jenkins', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Carmelo Anthony', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'PJ Tucker', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Tom Gugliotta', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Antoine Walker', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Ron Mercer', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Raef LaFrentz', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Laron Profit', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Andrei Kirilenko', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Jameer Nelson', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Paul Millsap', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Haywoode Workman', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Zydrunas Ilgauskas', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Matt Harpring', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Bostjan Nachbar', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Pape Sow', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Armen Gilliam', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'John Stockton', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Tiago Splitter', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Doron Lamb', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Miles Plumlee', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Corie Blount', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Tony Dumas', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Donyell Marshall', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Tony Delk', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Dahntay Jones', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Justin Reed', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Mychel Thompson', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Brandon Knight', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Quincy Pondexter', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Lou Williams', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Mike Miller', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Derek Fisher', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Anthony Carter', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Ron Harper', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'John Starks', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Sean Higgins', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Ed Pinckney', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Greg Stiemsma', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Jeremy Pargo', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Nando De Colo', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Pablo Prigioni', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Jon Barry', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Jason Kidd', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Jeff Malone', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Joe Courtney', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Wesley Person', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Nazr Mohammed', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Ricky Davis', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Nikoloz Tskitishvili', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Darko Milicic', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Rodrigue Beaubois', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Devin Harris', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Alvin Williams', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'DeSagana Diop', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Drew Gooden', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Travis Outlaw', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Anthony Mason', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Sam Perkins', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Chucky Brown', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Ben Uzoh', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'J.J. Barea', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Randy Woods', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Sam Cassell', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Reggie Jordan', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Greg Buckner', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Rafer Alston', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Josh Powell', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Luke Harangody', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Chandler Parsons', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Matt Fish', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Scott Padgett', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Keith Van Horn', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Joe Johnson', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Dan Gadzuric', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Rasual Butler', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Andrew Lang', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Andrew Lang', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Rod Strickland', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'John Lucas III', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Olden Polynice', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Dominic McGuire', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Dominique Jones', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Trevor Ariza', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Gary Trent', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Kurt Thomas', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Sherman Douglas', 'season': 1997}
# Document already exists and no update needed: {'full_name': 'Jalen Rose', 'season': 1995}
# Document already exists and no update needed: {'full_name': 'Metta World Peace', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Jake Voskuhl', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Travis Outlaw', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Andre Barrett', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Jackie Butler', 'season': 2005}
# Document already exists and no update needed: {'full_name': 'Daniel Gibson', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Manny Harris', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Paul Millsap', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Greg Monroe', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Greg Ostertag', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Calvin Booth', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Adonal Foyle', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Carlos Arroyo', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Mo Williams', 'season': 2011}
# Document already exists and no update needed: {'full_name': 'Emeka Okafor', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Viktor Khryapa', 'season': 2006}
# Document already exists and no update needed: {'full_name': 'Alexander Johnson', 'season': 2007}
# Document already exists and no update needed: {'full_name': 'Gary Payton', 'season': 1996}
# Document already exists and no update needed: {'full_name': 'Will Conroy', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Norris Cole', 'season': 2012}
# Document already exists and no update needed: {'full_name': 'Eric Gordon', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Meyers Leonard', 'season': 2013}
# Document already exists and no update needed: {'full_name': 'Erick Strickland', 'season': 1997}

# %% [markdown]
# ### Close MongoDB Connection

# %%
client.close()

# %% [markdown]
# ## Stop Spark Session

# %%
spark.stop()
